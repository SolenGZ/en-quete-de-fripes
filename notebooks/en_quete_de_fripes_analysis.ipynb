# %%
# En quête de fripes  
## Analyse des flux et impacts des vêtements usagés

Projet réalisé dans le cadre du bootcamp Data Analytics du Wagon.

# %%
## Contexte
Ce notebook vise à documenter la démarche d’analyse de données
ayant conduit à la présentation finale du projet « En quête de fripes ».

L’objectif est de rendre l’analyse compréhensible.

# %%
## Objectifs de l’analyse
- Explorer les données disponibles sur le devenir des vêtements usagés
- Identifier des indicateurs clés
- Produire des visualisations claires
- Interpréter les résultats

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
## Données
Les données utilisées proviennent de sources ouvertes mentionnées
dans la présentation finale du projet.

Elles sont chargées et analysées ci-dessous.

# %%
## Données
Les données utilisées proviennent de sources ouvertes mentionnées
dans le document de cadrage.

Elles sont chargées et analysées ci-dessous.

# %%
## Conclusion (provisoire)
Ce notebook constitue une première étape de formalisation
de la démarche data derrière le projet.

Il sera enrichi progressivement.
